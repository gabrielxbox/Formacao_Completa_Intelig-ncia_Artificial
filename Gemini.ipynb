# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielxbox/Formacao_Completa_Intelig-ncia_Artificial/blob/main/Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="YOUR_API_KEY")

# %%
model = genai.GenerativeModel("gemini-1.5-pro")
conversation ="Voce é uma asistente"
response = model.generate_content(conversation)
print(response.test.strip())
